# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_parquet('data/1.parquet')
data
# Out:
#               rtctime        lat        lon  target_temperature  feature_c  \
# 0       1672911588170  68.860123  18.346718           -4.281718  20.947325
# 1       1672911588180  68.860123  18.346718           -4.281718  20.947325
# 2       1672911588190  68.860123  18.346718           -4.281718  20.947325
# 3       1672911588200  68.860123  18.346718           -4.281718  21.361129
# 4       1672911588210  68.860123  18.346718           -4.281718  21.361129
# ...               ...        ...        ...                 ...        ...
# 295913  1672914547760  69.146416  18.637976           14.746255   5.031831
# 295914  1672914547770  69.146416  18.637976           14.746255   5.031831
# 295915  1672914547780  69.146416  18.637976           14.746255   5.031831
# 295916  1672914547790  69.146416  18.637976           14.746255   5.031831
# 295917  1672914547800  69.146416  18.637976           14.746255   5.031831
#
# ...

# %%
plt.figure(figsize = (15,15))
plt.plot(data.rtctime, data.target_temperature)
plt.plot(data.rtctime, data.feature_c)
plt.plot(data.rtctime, data.feature_ct)
plt.plot(data.rtctime, data.ambient_temp)
plt.plot(data.rtctime, data.car_speed)
plt.plot(data.rtctime, data.soc)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (15,15))
plt.plot(data.rtctime, data.feature_motorspeed)
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.plot(data.soc, data.ambient_temp)
plt.plot(data.soc, data.target_temperature)
plt.plot(data.soc, data.feature_c)
plt.plot(data.soc, data.feature_ct)
plt.legend()
plt.show()

# %%
corr_data = data[['target_temperature', 'feature_c', 'feature_ct', 'feature_motorspeed', 'ambient_temp', 'car_speed', 'soc']].corr()
sns.heatmap(corr_data, annot=True)

# %%
data2 = pd.read_parquet('data/16.parquet')
data2
# Out:
#               rtctime        lat        lon  target_temperature  feature_c  \
# 0       1672980787010  69.929291  23.261169          -20.591409  20.788170
# 1       1672980787020  69.929291  23.261169          -20.591409  20.788170
# 2       1672980787030  69.929291  23.261169          -20.591409  20.788170
# 3       1672980787040  69.929291  23.261169          -20.591409  20.788170
# 4       1672980787050  69.929291  23.261169          -20.591409  20.215212
# ...               ...        ...        ...                 ...        ...
# 497738  1672985766030  70.432060  24.506777           52.802200  18.941973
# 497739  1672985766040  70.432060  24.506777           52.802200  18.655495
# 497740  1672985766050  70.432060  24.506777           52.802200  18.082536
# 497741  1672985766060  70.432060  24.506777           52.802200  17.891550
# 497742  1672985766070  70.432060  24.506777           52.802200  18.178030
#
# ...
