# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_parquet('data/full_data.parquet')
data
# Out:
#               rtctime        lat        lon  target_temperature  feature_c  \
# 0       1672911588170  68.860123  18.346718           -4.281718  20.947325
# 1       1672911588180  68.860123  18.346718           -4.281718  20.947325
# 2       1672911588190  68.860123  18.346718           -4.281718  20.947325
# 3       1672911588200  68.860123  18.346718           -4.281718  21.361129
# 4       1672911588210  68.860123  18.346718           -4.281718  21.361129
# ...               ...        ...        ...                 ...        ...
# 253665  1673371992330  64.251831  20.245625           52.802200   7.737465
# 253666  1673371992340  64.251831  20.245625           52.802200   7.737465
# 253667  1673371992350  64.251831  20.245625           52.802200   7.737465
# 253668  1673371992360  64.251831  20.245625           52.802200   7.737465
# 253669  1673371992370  64.251831  20.245625           52.802200   7.737465
#
# ...

# %%
data = data.reset_index()
data
# Out:
#           index        rtctime        lat        lon  target_temperature  \
# 0             0  1672911588170  68.860123  18.346718           -4.281718
# 1             1  1672911588180  68.860123  18.346718           -4.281718
# 2             2  1672911588190  68.860123  18.346718           -4.281718
# 3             3  1672911588200  68.860123  18.346718           -4.281718
# 4             4  1672911588210  68.860123  18.346718           -4.281718
# ...         ...            ...        ...        ...                 ...
# 8159714  253665  1673371992330  64.251831  20.245625           52.802200
# 8159715  253666  1673371992340  64.251831  20.245625           52.802200
# 8159716  253667  1673371992350  64.251831  20.245625           52.802200
# 8159717  253668  1673371992360  64.251831  20.245625           52.802200
# 8159718  253669  1673371992370  64.251831  20.245625           52.802200
#
#          feature_c  feature_ct  feature_motorspeed  ambient_temp  car_speed  \
# ...

# %%
data.drop(['index'],1,inplace=True)
data.shape
# Out:
# C:\Users\Yash\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# (8159719, 10)

# %%
data.shape
# Out:
# (8159719, 10)

# %%
data.rtctime.value_counts().values
# Out:
# array([2, 2, 2, ..., 1, 1, 1], dtype=int64)

# %%
# timestamps = []
# count = []
# timestamps.append(data.rtctime.value_counts().index)
# count.append(data.rtctime.value_counts().values)
# timestamps
# count
# # count_dict = {'timestamps':timestamps, 'count':count}
# # count_df = pd.DataFrame(count_dict)
# # count_df

# %%
data = data.drop_duplicates(subset = ['rtctime'], keep = 'first')
data.shape
# Out:
# (8156409, 10)

# %%
data.rtctime.value_counts()
# Out:
# 1672911588170    1
# 1673277772020    1
# 1673277772150    1
# 1673277772140    1
# 1673277772130    1
#                 ..
# 1673192351640    1
# 1673192351630    1
# 1673192351620    1
# 1673192351610    1
# 1673371992370    1
# Name: rtctime, Length: 8156409, dtype: int64

# %%
data = data.sort_values(by = 'rtctime', ascending = True)

# %%
data = data.reset_index()
data.drop(['index'],1,inplace=True)
# Out:
# C:\Users\Yash\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
plt.figure(figsize = (15,15))
plt.plot(data.index, data.target_temperature)
# plt.plot(data.rtctime, data.feature_c)
# plt.plot(data.rtctime, data.feature_ct)
plt.plot(data.index, data.ambient_temp)
plt.plot(data.index, data.car_speed)
plt.plot(data.index, data.soc)
plt.legend()
plt.show()
# Out:
# C:\Users\Yash\Anaconda3\lib\site-packages\pandas\core\indexes\range.py:839: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return super().__getitem__(key)

# %%
corr_data = data[['target_temperature', 'feature_c', 'feature_ct', 'feature_motorspeed', 'ambient_temp', 'car_speed', 'soc']].corr()
plt.figure(figsize = (9,9))
sns.heatmap(corr_data, annot=True)

# %%
X = data.drop(['rtctime','lat','lon','target_temperature'],1)
y = data['target_temperature']
std_scaler = StandardScaler()
X_scaled = std_scaler.fit_transform(X)
X_scaled

# %%
plt.figure(figsize = (12,12))
plt.plot(data.index, data.rtctime)
plt.show()
# Out:
# C:\Users\Yash\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Yash\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\Yash\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
data.rtctime.isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
data.isna().sum()
# Out:
# rtctime               0
# lat                   0
# lon                   0
# target_temperature    0
# feature_c             0
# feature_ct            0
# feature_motorspeed    0
# ambient_temp          0
# car_speed             0
# soc                   0
# dtype: int64

# %%
data.iloc[80000:80020]
# Out:
#              rtctime        lat        lon  target_temperature  feature_c  \
# 80000  1672912388440  68.892235  18.378193           12.027973   5.000000
# 80001  1672912388450  68.892235  18.378193           12.027973   5.000000
# 80002  1672912388460  68.892235  18.378193           12.027973   5.000000
# 80003  1672912388470  68.892235  18.378193           12.027973   5.000000
# 80004  1672912388480  68.892235  18.378193           12.027973   5.000000
# 80005  1672912388490  68.892235  18.378193           12.027973   5.000000
# 80006  1672912388500  68.892235  18.378193           12.027973   5.000000
# 80007  1672912388510  68.892235  18.378193           12.027973   5.000000
# 80008  1672912388520  68.892235  18.378193           12.027973   5.000000
# 80009  1672912388530  68.892235  18.378193           12.027973   5.000000
# 80010  1672912388540  68.892235  18.378193           12.027973   5.000000
# 80011  1672912388550  68.892235  18.378193           12.027973   5.000000
# ...

# %%
plt.figure(figsize = (10,10))
# plt.plot(data.soc, data.ambient_temp)
plt.plot(data.rtctime, data.target_temperature)
# plt.plot(data.soc, data.feature_c)
plt.plot(data.rtctime, data.feature_ct)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data.target_temperature)
plt.show()

# %%
data2 = pd.read_parquet('data/16.parquet')
data2
# Out:
#               rtctime        lat        lon  target_temperature  feature_c  \
# 0       1672980787010  69.929291  23.261169          -20.591409  20.788170
# 1       1672980787020  69.929291  23.261169          -20.591409  20.788170
# 2       1672980787030  69.929291  23.261169          -20.591409  20.788170
# 3       1672980787040  69.929291  23.261169          -20.591409  20.788170
# 4       1672980787050  69.929291  23.261169          -20.591409  20.215212
# ...               ...        ...        ...                 ...        ...
# 497738  1672985766030  70.432060  24.506777           52.802200  18.941973
# 497739  1672985766040  70.432060  24.506777           52.802200  18.655495
# 497740  1672985766050  70.432060  24.506777           52.802200  18.082536
# 497741  1672985766060  70.432060  24.506777           52.802200  17.891550
# 497742  1672985766070  70.432060  24.506777           52.802200  18.178030
#
# ...
